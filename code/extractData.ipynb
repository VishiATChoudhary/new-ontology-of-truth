# %%
import gzip
import shutil
import pandas as pd

# %%
# with gzip.open('data\combined_UK_politician_twitter_timelines_2016-01-01_to_2023-02-11_clean.csv.gzip', 'rb') as f_in:
#     with open('file.csv', 'wb') as f_out:
#         shutil.copyfileobj(f_in, f_out)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\Vishi\AppData\Local\Temp\ipykernel_35292\2418155452.py:1: SyntaxWarning: invalid escape sequence '\c'
#   with gzip.open('data\combined_UK_politician_twitter_timelines_2016-01-01_to_2023-02-11_clean.csv.gzip', 'rb') as f_in:

# %%
df = pd.read_csv(r"data\UK_Tweets.csv")
df.head()
# Out:
#                     id   author_id                 created_at  \
# 0  1623327563958427651  3131144855  2023-02-08 14:27:05+00:00
# 1  1623294431460818948  3131144855  2023-02-08 12:15:26+00:00
# 2  1622941374810148871  3131144855  2023-02-07 12:52:31+00:00
# 3  1622654214294970386  3131144855  2023-02-06 17:51:26+00:00
# 4  1622597311791505410  3131144855  2023-02-06 14:05:20+00:00
#
#                                        expanded_urls  retweeted  quoted  \
# 0  ['https://twitter.com/BorisJohnson/status/1623...      False   False
# 1                                                 []      False   False
# 2  ['https://twitter.com/BorisJohnson/status/1622...      False   False
# 3  ['https://twitter.com/BorisJohnson/status/1622...      False   False
# 4                                                 []      False   False
#
#    reply                                               text  retweet_count  \
# 0  False  Thank you President @ZelenskyyUa. Your powerfu...           4685
# ...
